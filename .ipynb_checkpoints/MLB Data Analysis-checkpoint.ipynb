# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# 資料來源:https://www.fangraphs.com/leaders.aspx?pos=all&stats=bat&lg=all&qual=y&type=8&season=2018&month=0&season1=2018&ind=0&team=0&rost=0&age=&filter=&players=0

# %%
p_df = pd.read_csv('2018 Pitchers Leaderboard.csv', index_col="Name")#投手的資料(投球局數大於50局)
b_df = pd.read_csv('2018 Batters Leaderboard.csv', index_col="Name")#打者的資料(打席數大於100)

# %%
p_df.head(10)
# Out:
#                        Team   W  L  SV   G  GS     IP    K/9  BB/9  HR/9  \
# Name
# Jacob deGrom           Mets  10  9   0  32  32  217.0  11.16  1.91  0.41
# Max Scherzer      Nationals  18  7   0  33  33  220.2  12.24  2.08  0.94
# Justin Verlander     Astros  16  9   0  34  34  214.0  12.20  1.56  1.18
# Chris Sale          Red Sox  12  4   0  27  27  158.0  13.50  1.94  0.63
# Gerrit Cole          Astros  15  5   0  32  32  200.1  12.40  2.88  0.85
# Patrick Corbin    Nationals  11  7   0  33  33  200.0  11.07  2.16  0.68
# Trevor Bauer        Indians  12  6   1  28  27  175.1  11.34  2.93  0.46
# Luis Severino       Yankees  19  8   0  32  32  191.1  10.35  2.16  0.89
# Corey Kluber        Indians  20  7   0  33  33  215.0   9.29  1.42  1.05
# Aaron Nola         Phillies  17  6   0  33  33  212.1   9.49  2.46  0.72
#
#                   BABIP    LOB%     GB%   HR/FB   ERA   FIP  xFIP  WAR  \
# Name
# Jacob deGrom      0.281  82.0 %  46.4 %   6.3 %  1.70  1.99  2.60  9.0
# ...

# %%
b_df.head(10)
# Out:
#                        Team    G   PA  HR    R  RBI  SB     BB%      K%  \
# Name
# Mookie Betts        Red Sox  136  614  32  129   80  30  13.2 %  14.8 %
# Mike Trout           Angels  140  608  39  101   79  24  20.1 %  20.4 %
# Jose Ramirez        Indians  157  698  39  110  105  34  15.2 %  11.5 %
# Alex Bregman         Astros  157  705  31  105  103  10  13.6 %  12.1 %
# Francisco Lindor    Indians  158  745  38  129   92  25   9.4 %  14.4 %
# Christian Yelich    Brewers  147  651  36  118  110  22  10.4 %  20.7 %
# Matt Chapman      Athletics  145  616  24  100   68   1   9.4 %  23.7 %
# Manny Machado        Padres  162  709  37   84  107  14   9.9 %  14.7 %
# Anthony Rendon    Nationals  136  597  24   88   92   2   9.2 %  13.7 %
# J.D. Martinez       Red Sox  150  649  43  111  130   6  10.6 %  22.5 %
#
#                     ISO    ...       AVG    OBP    SLG   wOBA  wRC+   BsR  \
# Name                       ...
# ...

# %%
#取出WAR>0的資料
#WAR全名Wins Above Replacement，WAR指的是球員的綜合評價，包含進攻跟防守在內，且投、打皆可以計算出的數據。
p_df2 = p_df[p_df['WAR']>0]
b_df2 = b_df[b_df['WAR']>0]

# %%
#用WAR分級， MVP(6+ WAR)、SuperStar(5~6WAR)、All_Star(4~5WAR)、Good Player(3~4WAR)、Solid Starter(2~3WAR)、Role Player(1~2WAR)、Scurb(0~1WAR)
bins = [0,1,2,3,4,5,6,15]
group_names = ['Scurb', 'Role Player', 'Solid Starter', 'Good Player', 'All_Star','SuperStar', 'MVP']
group_values = [0,1,2,3,4,5,6]

# %%
b_df2['WAR-bins'] = pd.cut(b_df2['WAR'], bins, labels =group_names, include_lowest=True)
b_df2[['WAR','WAR-bins']].head(10)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                    WAR   WAR-bins
# Name
# Mookie Betts      10.4        MVP
# Mike Trout         9.8        MVP
# Jose Ramirez       8.0        MVP
# Alex Bregman       7.6        MVP
# Francisco Lindor   7.6        MVP
# Christian Yelich   7.6        MVP
# Matt Chapman       6.5        MVP
# Manny Machado      6.2        MVP
# Anthony Rendon     6.2        MVP
# J.D. Martinez      5.9  SuperStar

# %%
p_df2['WAR-bins'] = pd.cut(p_df2['WAR'], bins, labels =group_names, include_lowest=True)
p_df2[['WAR','WAR-bins']].head(10)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                   WAR   WAR-bins
# Name
# Jacob deGrom      9.0        MVP
# Max Scherzer      7.4        MVP
# Justin Verlander  6.7        MVP
# Chris Sale        6.2        MVP
# Gerrit Cole       6.0  SuperStar
# Patrick Corbin    5.9  SuperStar
# Trevor Bauer      5.8  SuperStar
# Luis Severino     5.5  SuperStar
# Corey Kluber      5.5  SuperStar
# Aaron Nola        5.4  SuperStar

# %%
p_df2.head(10)
# Out:
#                        Team   W  L  SV   G  GS     IP    K/9  BB/9  HR/9  \
# Name
# Jacob deGrom           Mets  10  9   0  32  32  217.0  11.16  1.91  0.41
# Max Scherzer      Nationals  18  7   0  33  33  220.2  12.24  2.08  0.94
# Justin Verlander     Astros  16  9   0  34  34  214.0  12.20  1.56  1.18
# Chris Sale          Red Sox  12  4   0  27  27  158.0  13.50  1.94  0.63
# Gerrit Cole          Astros  15  5   0  32  32  200.1  12.40  2.88  0.85
# Patrick Corbin    Nationals  11  7   0  33  33  200.0  11.07  2.16  0.68
# Trevor Bauer        Indians  12  6   1  28  27  175.1  11.34  2.93  0.46
# Luis Severino       Yankees  19  8   0  32  32  191.1  10.35  2.16  0.89
# Corey Kluber        Indians  20  7   0  33  33  215.0   9.29  1.42  1.05
# Aaron Nola         Phillies  17  6   0  33  33  212.1   9.49  2.46  0.72
#
#                   BABIP    LOB%     GB%   HR/FB   ERA   FIP  xFIP  WAR  \
# Name
# Jacob deGrom      0.281  82.0 %  46.4 %   6.3 %  1.70  1.99  2.60  9.0
# ...

# %%
b_df2.head(10)
# Out:
#                        Team    G   PA  HR    R  RBI  SB     BB%      K%  \
# Name
# Mookie Betts        Red Sox  136  614  32  129   80  30  13.2 %  14.8 %
# Mike Trout           Angels  140  608  39  101   79  24  20.1 %  20.4 %
# Jose Ramirez        Indians  157  698  39  110  105  34  15.2 %  11.5 %
# Alex Bregman         Astros  157  705  31  105  103  10  13.6 %  12.1 %
# Francisco Lindor    Indians  158  745  38  129   92  25   9.4 %  14.4 %
# Christian Yelich    Brewers  147  651  36  118  110  22  10.4 %  20.7 %
# Matt Chapman      Athletics  145  616  24  100   68   1   9.4 %  23.7 %
# Manny Machado        Padres  162  709  37   84  107  14   9.9 %  14.7 %
# Anthony Rendon    Nationals  136  597  24   88   92   2   9.2 %  13.7 %
# J.D. Martinez       Red Sox  150  649  43  111  130   6  10.6 %  22.5 %
#
#                     ISO    ...        OBP    SLG   wOBA  wRC+   BsR   Off  \
# Name                       ...
# ...

# %%
def plotComparePitcherWAR():
    #不同等級投手與 ERA(防禦率)的散佈情形
    plt.figure(figsize=(8,4))
    sns.stripplot(x="WAR-bins", y="ERA", data=p_df2)
    plt.title("Pitcher")
    plt.grid()
    plt.show()

# %%
def plotCompareBatterWAR():
    #不同等級投手與 OBP(上壘率)的散佈情形
    plt.figure(figsize=(8,4))
    sns.stripplot(x="WAR-bins", y="OBP", data=b_df2)
    plt.title("Batter")
    plt.grid()
    plt.show()

# %%
def plotPitcherWAR():
    #每隊所擁有的投手WAR的分布情形
    plt.figure(dpi=100)
    ax = sns.stripplot(x="Team", y="WAR", data=p_df)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
    plt.title("Pitcher")
    plt.grid()
    plt.show()

# %%
def plotBatterWAR():
    #每隊所擁有的打者WAR的分布情形
    plt.figure(dpi=100)
    ax = sns.stripplot(x="Team", y="WAR", data=b_df)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
    plt.title("Batter")
    plt.grid()
    plt.show()

# %%
def findTeamWARbins():
    team_name = input("Please input your team name ")
    team_p = p_df2[p_df2['Team']==team_name]
    team_b = b_df2[b_df2['Team']==team_name]
    print(f"Player for {team_name}")
    print('Pitcher')
    display(team_p['WAR-bins'].value_counts().to_frame())
    print('Batter')
    display(team_b['WAR-bins'].value_counts().to_frame())

# %%
def select():
    selection = int(input('''please input your selcetion:
                            0. Close
                            1. Compare Pitcher Level with ERA
                            2. Compare Batter Level with OBP
                            3. Pitcher WAR
                            4. Batter WAR
                            5. Team WAR\n'''))

    while selection != 0:
        if selection == 1:
            plotComparePitcherWAR()
        elif selection == 2:
            plotCompareBatterWAR()
        elif selection == 3:
            plotPitcherWAR()
        elif selection == 4:
            plotBatterWAR()
        elif selection == 5:
            findTeamWARbins()
        else:
            print('Error Input')
        selection = int(input('''please input your selcetion:
                            0. Close
                            1. ComparePitcherWAR
                            2. CompareBatterWAR
                            3. PitcherWAR
                            4. BatterWAR
                            5. Team WAR\n'''))

# %%
select()
# Out:
# please input your selcetion:
#                             0. Close
#                             1. Compare Pitcher Level with ERA
#                             2. Compare Batter Level with OBP
#                             3. Pitcher WAR
#                             4. Batter WAR
#                             5. Team WAR
# 1
# please input your selcetion:
#                             0. Close
#                             1. ComparePitcherWAR
#                             2. CompareBatterWAR
#                             3. PitcherWAR
#                             4. BatterWAR
#                             5. Team WAR
# 2
# please input your selcetion:
#                             0. Close
#                             1. ComparePitcherWAR
#                             2. CompareBatterWAR
#                             3. PitcherWAR
#                             4. BatterWAR
#                             5. Team WAR
# 3
# please input your selcetion:
# ...
