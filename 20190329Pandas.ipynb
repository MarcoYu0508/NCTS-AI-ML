# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('grades.csv')

# %%
df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
# 5     13
# 6     11
# 7      8
# 8      9
# 9     10
# 10    14
# 11    13
# 12    11
# 13    15
# 14     8
# 15    11
# 16    14
# 17    12
# 18     9
# 19    14
# 20    13
# 21     9
# 22    12
# 23    10
# 24    10
# 25    13
# 26    13
# 27     8
# 28    15
# 29    14
#       ..
# 70     9
# 71     9
# 72    10
# 73    13
# 74    14
# 75    13
# 76     9
# 77    13
# 78    12
# 79     9
# 80    13
# 81    11
# 82    11
# 83    10
# 84    10
# 85    10
# 86    11
# 87    10
# 88    11
# 89    13
# 90     8
# 91    14
# 92     8
# 93    11
# 94    10
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %%
df.國文.hist(bins=15)

# %%
df.corr()
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %%
df.國文.corr(df.數學)
# Out:
# -0.3108989822179331

# %%
df['總級分'] = df.sum(axis=1)

# %%
df
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分
# 0   劉俊安   9  10  15  10  13   57
# 1   胡玉華  10  10  10   8   9   47
# 2   黃淑婷  13  15   8  11  14   61
# 3   陳上紫  10  10   8   9  14   51
# 4   崔靜成  13  12  14  12  13   64
# 5   張雅岳  13  12  12  12   8   57
# 6   梁俊翔  11  13  10  10  14   58
# 7   林金鳳   8   9  10  10   8   45
# 8   許協旺   9   9  12  10  10   50
# 9   郭雅惠  10  15  12  11   9   57
# 10  張志偉  14   9   8  10  12   53
# 11  周皇樺  13   9  13  14  15   64
# 12  李正偉  11  15  11  14  15   66
# 13  黃旭忠  15  14   9  12  10   60
# 14  葉雅琳   8  13  10  13  14   58
# 15  黃淑慧  11   8  10  12  15   56
# 16  吳芝菁  14   9  11  10   9   53
# 17  聶珮君  12  11  13  12   9   57
# 18  梁慧君   9   8   8   8  12   45
# 19  葉曉玲  14   9  11  15   9   58
# 20  陳智超  13   9  13  14  13   62
# 21  黃奕霞   9   8  11  13   8   49
# 22  沈昆純  12  14  10   9   9   54
# 23  許惠雯  10  13  12  14  10   59
# 24  陳竹伯  10  12  15  10  14   61
# 25  蔡亦瑄  13  13  14  13  12   65
# 26  戴喜寶  13  11   9  14   9   56
# ...

# %%
df['加權'] = df.數學*2+df.英文*1.5+df.自然*1.5

# %%
df2 = df.sort_values(by = '總級分',ascending=False)

# %%
df2 = df2.sort_values(by = ['加權','總級分'],ascending=False)

# %%
df2.index = range(1,101)

# %%
df2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分    加權
# 1  李士賢  10  14  15  13  13   65  70.5
# 2  胡淳茜  12  15  14  13  11   65  70.0
# 3  劉麗芬   8  14  14  14  14   64  70.0
# 4  邱盈俊  10  14  14  13   8   59  68.5
# 5  俞志峰   9  14  13  14  15   65  68.0

# %%
df2[(df2.數學==15)&(df2.英文>13)]
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分    加權
# 1   李士賢  10  14  15  13  13   65  70.5
# 14  吳志遠  13  15  15   8   8   59  64.5

# %%
df2.drop("總級分",axis=1,inplace=True)

# %%
#刪掉一列
df2.drop(df2[df2.姓名=="劉麗芬"].index).head()
# Out:
#     姓名  國文  英文  數學  自然  社會    加權
# 1  李士賢  10  14  15  13  13  70.5
# 2  胡淳茜  12  15  14  13  11  70.0
# 4  邱盈俊  10  14  14  13   8  68.5
# 5  俞志峰   9  14  13  14  15  68.0
# 6  曾怡君  11  12  15  13  14  67.5

# %%
df2[df2.姓名!="劉麗芬"].head()
# Out:
#     姓名  國文  英文  數學  自然  社會    加權
# 1  李士賢  10  14  15  13  13  70.5
# 2  胡淳茜  12  15  14  13  11  70.0
# 4  邱盈俊  10  14  14  13   8  68.5
# 5  俞志峰   9  14  13  14  15  68.0
# 6  曾怡君  11  12  15  13  14  67.5

# %%
mydata = np.random.randn(4,3)

# %%
mydata
# Out:
# array([[-0.24719601, -1.26086038, -0.9004156 ],
#        [ 1.72197034, -1.61579214, -0.72829257],
#        [-3.4086777 , -1.82301693,  0.49427418],
#        [-2.14067133, -0.13136552,  1.6246183 ]])

# %%
dfr = pd.DataFrame(mydata,columns=list('ABC'))

# %%
dfr
# Out:
#           A         B         C
# 0 -0.247196 -1.260860 -0.900416
# 1  1.721970 -1.615792 -0.728293
# 2 -3.408678 -1.823017  0.494274
# 3 -2.140671 -0.131366  1.624618

# %%
dfr2 = pd.DataFrame(np.random.randn(3,3),columns=list('ABC'))

# %%
dfr3 = pd.concat([dfr,dfr2],axis=0)

# %%
dfr3.index=range(7)

# %%
dfr3
# Out:
#           A         B         C
# 0 -0.247196 -1.260860 -0.900416
# 1  1.721970 -1.615792 -0.728293
# 2 -3.408678 -1.823017  0.494274
# 3 -2.140671 -0.131366  1.624618
# 4 -0.448128 -2.217524 -0.085286
# 5 -0.895828  0.430194 -0.419329
# 6  1.512715 -0.364858  1.535446

# %%
pd.concat([dfr,dfr2],axis=1).fillna(0)
# Out:
#           A         B         C         A         B         C
# 0 -0.247196 -1.260860 -0.900416 -0.448128 -2.217524 -0.085286
# 1  1.721970 -1.615792 -0.728293 -0.895828  0.430194 -0.419329
# 2 -3.408678 -1.823017  0.494274  1.512715 -0.364858  1.535446
# 3 -2.140671 -0.131366  1.624618  0.000000  0.000000  0.000000
