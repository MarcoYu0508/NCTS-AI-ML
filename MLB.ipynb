# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import

# %%
df = pd.read_csv('FanGraphs Leaderboard.csv', index_col="Name")

# %%
df
# Out:
#                            Team    G   PA  HR    R  RBI  SB     BB%      K%  \
# Name
# Mookie Betts            Red Sox  136  614  32  129   80  30  13.2 %  14.8 %
# Mike Trout               Angels  140  608  39  101   79  24  20.1 %  20.4 %
# Jose Ramirez            Indians  157  698  39  110  105  34  15.2 %  11.5 %
# Alex Bregman             Astros  157  705  31  105  103  10  13.6 %  12.1 %
# Francisco Lindor        Indians  158  745  38  129   92  25   9.4 %  14.4 %
# Christian Yelich        Brewers  147  651  36  118  110  22  10.4 %  20.7 %
# Matt Chapman          Athletics  145  616  24  100   68   1   9.4 %  23.7 %
# Manny Machado             - - -  162  709  37   84  107  14   9.9 %  14.7 %
# Anthony Rendon        Nationals  136  597  24   88   92   2   9.2 %  13.7 %
# J.D. Martinez           Red Sox  150  649  43  111  130   6  10.6 %  22.5 %
# Nolan Arenado           Rockies  156  673  38  104  110   2  10.8 %  18.1 %
# ...

# %%
df = df[df['WAR']>0]

# %%
df
# Out:
#                            Team    G   PA  HR    R  RBI  SB     BB%      K%  \
# Name
# Mookie Betts            Red Sox  136  614  32  129   80  30  13.2 %  14.8 %
# Mike Trout               Angels  140  608  39  101   79  24  20.1 %  20.4 %
# Jose Ramirez            Indians  157  698  39  110  105  34  15.2 %  11.5 %
# Alex Bregman             Astros  157  705  31  105  103  10  13.6 %  12.1 %
# Francisco Lindor        Indians  158  745  38  129   92  25   9.4 %  14.4 %
# Christian Yelich        Brewers  147  651  36  118  110  22  10.4 %  20.7 %
# Matt Chapman          Athletics  145  616  24  100   68   1   9.4 %  23.7 %
# Manny Machado             - - -  162  709  37   84  107  14   9.9 %  14.7 %
# Anthony Rendon        Nationals  136  597  24   88   92   2   9.2 %  13.7 %
# J.D. Martinez           Red Sox  150  649  43  111  130   6  10.6 %  22.5 %
# Nolan Arenado           Rockies  156  673  38  104  110   2  10.8 %  18.1 %
# ...

# %%
bins = [0,1,2,3,4,5,6,15]
bins
# Out:
# [0, 1, 2, 3, 4, 5, 6, 15]

# %%
group_names = ['Scurb', 'Role Player', 'Solid Starter', 'Good Player', 'All_Star','SuperStar', 'MVP']
group_values = [0,1,2,3,4,5,6]

# %%
df['WAR-bins'] = pd.cut(df['WAR'], bins, labels =group_names, include_lowest=True)
df['Values'] = pd.cut(df['WAR'], bins, labels =group_values, include_lowest=True)
df[['WAR','WAR-bins','Values']]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                     WAR     WAR-bins Values
# Name
# Mookie Betts       10.4          MVP      6
# Mike Trout          9.8          MVP      6
# ...

# %%
df
# Out:
#                            Team    G   PA  HR    R  RBI  SB     BB%      K%  \
# Name
# Mookie Betts            Red Sox  136  614  32  129   80  30  13.2 %  14.8 %
# Mike Trout               Angels  140  608  39  101   79  24  20.1 %  20.4 %
# Jose Ramirez            Indians  157  698  39  110  105  34  15.2 %  11.5 %
# Alex Bregman             Astros  157  705  31  105  103  10  13.6 %  12.1 %
# Francisco Lindor        Indians  158  745  38  129   92  25   9.4 %  14.4 %
# Christian Yelich        Brewers  147  651  36  118  110  22  10.4 %  20.7 %
# Matt Chapman          Athletics  145  616  24  100   68   1   9.4 %  23.7 %
# Manny Machado             - - -  162  709  37   84  107  14   9.9 %  14.7 %
# Anthony Rendon        Nationals  136  597  24   88   92   2   9.2 %  13.7 %
# J.D. Martinez           Red Sox  150  649  43  111  130   6  10.6 %  22.5 %
# Nolan Arenado           Rockies  156  673  38  104  110   2  10.8 %  18.1 %
# ...

# %%
df.loc['Mike Trout']
# Out:
# Team        Angels
# G              140
# PA             608
# HR              39
# R              101
# RBI             79
# SB              24
# BB%         20.1 %
# K%          20.4 %
# ISO          0.316
# BABIP        0.346
# AVG          0.312
# OBP           0.46
# SLG          0.628
# wOBA         0.447
# wRC+           191
# BsR              5
# Off           71.1
# Def            4.2
# WAR            9.8
# playerid     10155
# WAR-bins       MVP
# Values           6
# Name: Mike Trout, dtype: object

# %%
from ipywidgets import interact

# %%
def searchPlayer(name):
    print(name)
    print(df.loc[name])

# %%
interact(searchPlayer,name="Mike Trout")
# Out:
# A Jupyter Widget
# <function __main__.searchPlayer>

# %%
a = df['Values'].loc["Mike Trout"]

# %%
a
# Out:
# 6
